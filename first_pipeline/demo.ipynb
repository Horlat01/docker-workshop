# %%
import pandas as pd
import os

# %%
files = os.listdir('/workspaces/docker-workshop/first_pipeline/output')
print(files)
# Out:
# ['first_pipeline_output_month_12.parquet', 'first_pipeline_output_month_12.csv', 'output']

# %%
for files in os.listdir('/workspaces/docker-workshop/first_pipeline/output'):
    print(files)
# Out:
# first_pipeline_output_month_12.parquet
# first_pipeline_output_month_12.csv
# output

# %%
for files in os.listdir('/workspaces/docker-workshop/first_pipeline/output *.csv'):
       print(files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 for files in os.listdir('/workspaces/docker-workshop/first_pipeline/output *.csv'):
#       2        print(files)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/docker-workshop/first_pipeline/output *.csv'
